# %% [markdown]
# ## HOLIDAYS

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
holidays = pd.read_csv("data/us-federal-holidays-2011-2020.csv")

# %%
data2.head()
# Out:
#          Date                              Holiday
# 0  12/31/2010                       New Year's Day
# 1   1/17/2011  Birthday of Martin Luther King, Jr.
# 2   2/21/2011                Washington's Birthday
# 3   5/30/2011                         Memorial Day
# 4    7/4/2011                     Independence Day

# %%
print(type(data2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data2.dtypes
# Out:
# Date       object
# Holiday    object
# dtype: object

# %%
print(min(data2["Date"]))
print(max(data2["Date"]))
# Out:
# 1/1/2013
# 9/7/2020

# %%
# Conversion objet 'date' en datetime format
data2['Date'] = pd.to_datetime(data2['Date'])

# %%
data2.head(10)
# Out:
#         Date                              Holiday
# 0 2010-12-31                       New Year's Day
# 1 2011-01-17  Birthday of Martin Luther King, Jr.
# 2 2011-02-21                Washington's Birthday
# 3 2011-05-30                         Memorial Day
# 4 2011-07-04                     Independence Day
# 5 2011-09-05                            Labor Day
# 6 2011-10-10                         Columbus Day
# 7 2011-11-11                         Veterans Day
# 8 2011-11-24                     Thanksgiving Day
# 9 2011-12-26                        Christmas Day

# %%
print(type(data2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = data2[(data2['Date'] >= "2011-09-01") & (data2['Date'] <= "2013-03-05")]

# %%
# Out:
#                        Date                Holiday
# count                    18                     18
# unique                   18                     10
# top     2012-11-22 00:00:00  Washington's Birthday
# freq                      1                      2
# first   2011-09-05 00:00:00                    NaN
# last    2013-02-18 00:00:00                    NaN

# %%
data2.loc[data2['Date'] == "2010-12-31"]
# Out:
#         Date         Holiday
# 0 2010-12-31  New Year's Day

# %%
holi = pd.read_csv('data/HolidayDateList-Table 1.csv', delimiter=";")

# %%
holi.head(20)
# Out:
#     DAY_DATE   DAY_INT                 HOLIDAY_NAME   WEEKDAY  \
# 0     1/1/10  20100101               New Year's Day    Friday
# 1    1/18/10  20100118       Martin Luther King Day    Monday
# 2    2/15/10  20100215              Presidents' Day    Monday
# 3     4/2/10  20100402                  Good Friday    Friday
# 4    5/31/10  20100531                 Memorial Day    Monday
# 5     7/4/10  20100704             Independence Day    Sunday
# 6     7/5/10  20100705  Independence Day (observed)    Monday
# 7     9/6/10  20100906                    Labor Day    Monday
# 8   10/11/10  20101011                 Columbus Day    Monday
# 9   11/11/10  20101111                 Veterans Day  Thursday
# 10  11/25/10  20101125             Thanksgiving Day  Thursday
# 11  12/24/10  20101224     Christmas Day (observed)    Friday
# 12  12/25/10  20101225                Christmas Day  Saturday
# 13  12/31/10  20101231    New Year's Day (observed)    Friday
# ...

# %%
holi.dtypes
# Out:
# DAY_DATE                 object
# DAY_INT                   int64
# HOLIDAY_NAME             object
# WEEKDAY                  object
# HOLIDAY_DATE_SRC         object
# IS_HOL                    int64
# IS_FRB_BANK_OBS_HOL       int64
# IS_NYSE_OBS_HOL           int64
# IS_US_FEDERAL_OBS_HOL     int64
# dtype: object

# %%
holi['DAY_DATE'] = pd.to_datetime(holi['DAY_DATE'])

# %%
holi2 = holi[['DAY_DATE', 'WEEKDAY', 'IS_HOL']]

# %%
holi2.head()
# Out:
#   DAY_DATE WEEKDAY  IS_HOL
# 0   1/1/10  Friday       1
# 1  1/18/10  Monday       1
# 2  2/15/10  Monday       1
# 3   4/2/10  Friday       1
# 4  5/31/10  Monday       1

# %%
holi2['DAY_DATE'] = pd.to_datetime(holi2['DAY_DATE'])
# Out:
# /Users/jordanvidal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
holi2.dtypes
# Out:
# DAY_DATE    datetime64[ns]
# WEEKDAY             object
# IS_HOL               int64
# dtype: object

# %%
print(min(holi2['DAY_DATE']))
print(max(holi2['DAY_DATE']))
# Out:
# 2010-01-01 00:00:00
# 2020-12-25 00:00:00

# %% [markdown]
# ## SUPER BOWL

# %%
sb = pd.read_csv('data/Super_Bowl.csv', delimiter=';')
sb.head(25)
# Out:
#          Date     SB  Attendance                    QB  Winner  \
# 0   15-Jan-67      I       61946                    Bart Starr
# 1   14-Jan-68     II       75546                    Bart Starr
# 2   12-Jan-69    III       75389                    Joe Namath
# 3   11-Jan-70     IV       80562   Len Dawson; Mike Livingston
# 4   17-Jan-71      V       79204  Earl Morrall ; Johnny Unitas
# 5   16-Jan-72     VI       81023                Roger Staubach
# 6   14-Jan-73    VII       90182                    Bob Griese
# 7   13-Jan-74   VIII       71882                    Bob Griese
# 8   12-Jan-75     IX       80997                Terry Bradshaw
# 9   18-Jan-76      X       80187                Terry Bradshaw
# 10   9-Jan-77     XI      103438                 Kenny Stabler
# 11  15-Jan-78    XII       76400                Roger Staubach
# 12  21-Jan-79   XIII       79484                Terry Bradshaw
# 13  20-Jan-80    XIV      103985                Terry Bradshaw
# ...

# %%
sb.dtypes
# Out:
# Date                object
# SB                  object
# Attendance           int64
# QB  Winner          object
# Coach Winner        object
# Winner              object
# Winning Pts          int64
# QB Loser            object
# Coach Loser         object
# Loser               object
# Losing Pts           int64
# MVP                 object
# Stadium             object
# City                object
# State               object
# Point Difference     int64
# Referee             object
# Umpire              object
# Head Linesman       object
# Line Judge          object
# Field Judge         object
# Back Judge          object
# Side Judge          object
# dtype: object

# %%
# Conversion objet 'date' en datetime format
sb['Date'] = pd.to_datetime(sb['Date'])

# %%
print(min(sb['Date']))
print(max(sb['Date']))
# Out:
# 1967-01-15 00:00:00
# 2017-02-05 00:00:00

# %%
superbowl = sb[['Date','City']]
superbowl.head()
# Out:
#         Date         City
# 0 1967-01-15  Los Angeles
# 1 1968-01-14        Miami
# 2 1969-01-12        Miami
# 3 1970-01-11  New Orleans
# 4 1971-01-17        Miami

# %%
print(min(superbowl['Date']))
print(max(superbowl['Date']))
# Out:
# 1967-01-15 00:00:00
# 2017-02-05 00:00:00

# %%
superbowl.loc[superbowl['Date'] == '2017-02-05']
# Out:
#          Date     City
# 50 2017-02-05  Houston

# %%
superbowl[45:47]
# Out:
#          Date          City
# 45 2012-02-05  Indianapolis
# 46 2013-02-03   New Orleans

# %% [markdown]
# ## HOLIDAYS API

# %%
import requests
# headers = {'Authorization': 'token d597a785-bbb3-4411-aac4-ce054c0f661f'}
response = requests.get("https://holidayapi.com/v1/holidays?key=d597a785-bbb3-4411-aac4-ce054c0f661f&country=US&year=2011") 
test = response.json()

# %%
print(response)
# Out:
# <Response [200]>

# %%
test
# Out:
# {'holidays': {'2011-01-01': [{'date': '2011-01-01',
#     'name': "Durin's Day",
#     'observed': '2010-12-31',
#     'public': True}],
#   '2011-02-23': [{'date': '2011-02-23',
#     'name': "Founder's Day",
#     'observed': '2011-02-23',
#     'public': True}],
#   '2011-03-20': [{'date': '2011-03-20',
#     'name': 'Weasel Stomping Day',
#     'observed': '2011-03-20',
#     'public': False}],
#   '2011-04-05': [{'date': '2011-04-05',
#     'name': 'First Contact Day',
#     'observed': '2011-04-05',
#     'public': False}],
#   '2011-04-06': [{'date': '2011-04-06',
#     'name': 'Second Contact Day',
#     'observed': '2011-04-06',
#     'public': False}],
#   '2011-05-10': [{'date': '2011-05-10',
#     'name': 'Whacking Day',
#     'observed': '2011-05-10',
#     'public': False}],
#   '2011-05-25': [{'date': '2011-05-25',
#     'name': 'The Glorious Twenty-Fifth of May',
#     'observed': '2011-05-25',
#     'public': False}],
#   '2011-06-22': [{'date': '2011-06-22',
# ...
